# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# input\data\test\benign\img_4542.jpg
# input\data\test\benign\img_4543.jpg
# input\data\test\benign\img_4544.jpg
# input\data\test\benign\img_4545.jpg
# input\data\test\benign\img_4546.jpg
# input\data\test\benign\img_4547.jpg
# input\data\test\benign\img_4548.jpg
# input\data\test\benign\img_4549.jpg
# input\data\test\benign\img_4550.jpg
# input\data\test\benign\img_4551.jpg
# input\data\test\benign\img_4552.jpg
# input\data\test\benign\img_4553.jpg
# input\data\test\benign\img_4554.jpg
# input\data\test\benign\img_4555.jpg
# input\data\test\benign\img_4556.jpg
# input\data\test\benign\img_4557.jpg
# input\data\test\benign\img_4558.jpg
# input\data\test\benign\img_4559.jpg
# input\data\test\benign\img_4560.jpg
# input\data\test\benign\img_4561.jpg
# input\data\test\benign\img_4562.jpg
# input\data\test\benign\img_4563.jpg
# input\data\test\benign\img_4564.jpg
# input\data\test\benign\img_4565.jpg
# input\data\test\benign\img_4566.jpg
# input\data\test\benign\img_4567.jpg
# ...

# %%
#import libraries
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image
from sklearn.preprocessing import StandardScaler 
from sklearn.metrics import accuracy_score
import keras
from keras.applications import VGG19,Xception,VGG16
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam, RMSprop
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.resnet50 import ResNet50
from keras import layers
import tensorflow as tf

# %%
#import  train test data 
## loading training set
train_datagen = ImageDataGenerator(rescale=1/255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   vertical_flip =  True , 
                                   rotation_range=40,
                                   brightness_range = (0.5, 1.5),
                                   horizontal_flip = True)

train_data = train_datagen.flow_from_directory(
    'input/data/train',   target_size = (64, 64),
                                                 class_mode='sparse',
                                                 shuffle=True,seed=1)


## loading validation dataset
test_datagen =  ImageDataGenerator(rescale=1/255)
test_data =   test_datagen.flow_from_directory(
    'input/data/test',   target_size = (64, 64),
                                                 class_mode='sparse',
                                                 shuffle=True,seed=1)
# Out:
# Found 8940 images belonging to 2 classes.
# Found 2723 images belonging to 2 classes.

# %%
#display classes names
class_names = ["Absent","Present"]
for i in class_names :
    print(class_names.index(i),"  ",i)
# Out:
# 0    Absent
# 1    Present

# %%
#visulaize test_data
fig, ax = plt.subplots()
ax.bar(["benign"],[300],color= "r",label='benign')
ax.bar(["malignat"],[360],color ="b",label ="malignat")
ax.legend()

# %%
#visualize data
fig, axis = plt.subplots()
axis.bar("test_data", 572, color='g', label='Test Data')
axis.bar("train_data",1148 , color='y', label='Train Data')
legend = axis.legend()

# %%
from keras.preprocessing import image
import numpy as np
image_path = "input/data/test/benign/img_4564.jpg"
new_img = image.load_img(image_path, target_size=(244, 244))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
print("Absent")
plt.imshow(new_img)
# Out:
# Absent

# %%
from keras.preprocessing import image
import numpy as np
image_path = "input/data/test/malignant/img_4431.jpg"
new_img = image.load_img(image_path, target_size=(244, 244))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
print("Present")
plt.imshow(new_img)
# Out:
# Present

# %%
## Defining Cnn
model = tf.keras.models.Sequential([
  layers.BatchNormalization(),
  layers.Conv2D(32, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.3),
  layers.Conv2D(128, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Conv2D(256, 3, activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(512, activation='relu'),
  layers.Dropout(0.15),
  layers.Dense(2, activation= 'softmax')
])

# %%
#compile the model
import tensorflow as tf
model.compile(optimizer="adam", loss=keras.losses.SparseCategoricalCrossentropy(), metrics=['accuracy'])

#early stopping function
early = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5)

# %%
#fit the model
histroy=model.fit(train_data,
    validation_data = test_data, 
    callbacks=[early],
    epochs = 50)
# Out:
# Epoch 1/50
# 280/280 [==============================] - 429s 2s/step - loss: 0.6185 - accuracy: 0.6562 - val_loss: 0.6014 - val_accuracy: 0.6798
# Epoch 2/50
# 280/280 [==============================] - 127s 453ms/step - loss: 0.5425 - accuracy: 0.7276 - val_loss: 0.4353 - val_accuracy: 0.8116
# Epoch 3/50
# 280/280 [==============================] - 125s 448ms/step - loss: 0.5031 - accuracy: 0.7540 - val_loss: 0.3820 - val_accuracy: 0.8336
# Epoch 4/50
# 280/280 [==============================] - 129s 461ms/step - loss: 0.4562 - accuracy: 0.7848 - val_loss: 0.3487 - val_accuracy: 0.8336
# Epoch 5/50
# 280/280 [==============================] - 129s 460ms/step - loss: 0.4170 - accuracy: 0.8070 - val_loss: 0.2858 - val_accuracy: 0.8649
# Epoch 6/50
# 280/280 [==============================] - 131s 466ms/step - loss: 0.3772 - accuracy: 0.8317 - val_loss: 0.2766 - val_accuracy: 0.8869
# Epoch 7/50
# ...

# %%
#evulate training model
train_res= model.evaluate(train_data)
train_acc = train_res[1]
train_err = train_res[0]
print('Accuracy of training data', train_acc)
print('Error of training data', train_err)
# Out:
# 280/280 [==============================] - 84s 300ms/step - loss: 0.0665 - accuracy: 0.9767
# Accuracy of training data 0.9767338037490845
# Error of training data 0.06652618199586868

# %%
#evaluate test model
test_res= model.evaluate(test_data)
test_acc = test_res[1]
test_err = test_res[0]
print('Accuracy of testing data', test_acc)
print('Error of testing data', test_err)
# Out:
# 86/86 [==============================] - 18s 207ms/step - loss: 0.0537 - accuracy: 0.9805
# Accuracy of testing data 0.980536162853241
# Error of testing data 0.05370202660560608

# %%
try:
    assert train_acc>test_acc,"Assertion Failed, Model has to be built again... " 
except:
    print('Assertion passed..')
print(train_acc)
print(test_acc)
# Out:
# Assertion passed..
# 0.9767338037490845
# 0.980536162853241

# %%
#plotting training values
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

acc = histroy.history['accuracy']
val_acc = histroy.history['val_accuracy']
loss = histroy.history['loss']
val_loss = histroy.history['val_loss']
epochs = range(1, len(loss) + 1)

#accuracy plot
plt.plot(epochs, acc, color='green', label='Training Accuracy')
plt.plot(epochs, val_acc, color='blue', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.figure()
#loss plot
plt.plot(epochs, loss, color='pink', label='Training Loss')
plt.plot(epochs, val_loss, color='red', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
#predict val data
y_pred = model.predict(test_data)
y_pred =  np.argmax(y_pred,axis=1)

print(y_pred)
# Out:
# [1 0 0 ... 0 0 0]

# %%
#example 1
from keras.preprocessing import image
import numpy as np
image_path = "input/data/test/benign/img_4574.jpg"
new_img = image.load_img(image_path, target_size=(64, 64))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
prediction = model.predict(img)
prediction = np.argmax(prediction,axis=1)
print(prediction)
print(class_names[prediction[0]])
plt.imshow(new_img)
# Out:
# [0]
# Benign

# %%
#example 2
from keras.preprocessing import image
import numpy as np
image_path = "input/data/test/malignant/img_4416.jpg"
new_img = image.load_img(image_path, target_size=(64, 64))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
prediction = model.predict(img)
prediction = np.argmax(prediction,axis=1)
print(prediction)
print(class_names[prediction[0]])
plt.imshow(new_img)
# Out:
# [1]
# Malignant

# %%
#example 3
from keras.preprocessing import image
import numpy as np
image_path = "input/data/test/benign/img_4620.jpg"
new_img = image.load_img(image_path, target_size=(64, 64))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
prediction = model.predict(img)
prediction = np.argmax(prediction,axis=1)
print(prediction)
print(class_names[prediction[0]])
plt.imshow(new_img)
# Out:
# [0]
# Benign

# %%
#example 3=4
from keras.preprocessing import image
import numpy as np
image_path = "input/data/test/malignant/img_4447.jpg"
new_img = image.load_img(image_path, target_size=(64, 64))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
prediction = model.predict(img)
prediction = np.argmax(prediction,axis=1)
print(prediction)
print(class_names[prediction[0]])
plt.imshow(new_img)
# Out:
# [1]
# Malignant

# %%
#save file as h5 model
from keras.models import model_from_json

model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save("model_brain.h5")

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
model.save("brain_cancer")
# Out:
# INFO:tensorflow:Assets written to: brain_cancer\assets

# %%
reconstructed_model = keras.models.load_model("brain_cancer")

# %%
result = reconstructed_model.predict(img)
prediction = np.argmax(result,axis=1)
print(prediction)
print(class_names[prediction[0]])
plt.imshow(new_img)
# Out:
# [1]
# Malignant
